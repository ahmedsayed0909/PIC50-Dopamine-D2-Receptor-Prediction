# %% [markdown]
# # Data Cleaning and Validation

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('..\Data\Dopamine_D2_receptor_01_bioactivity_data_raw.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\HP\AppData\Local\Temp\ipykernel_11068\3957931753.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('..\Data\Dopamine_D2_receptor_01_bioactivity_data_raw.csv')

# %%
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0         NaN              NaN        32111                  []
# 1         NaN              NaN        33282                  []
# 2         NaN              NaN        38258                  []
# 3         NaN              NaN        39387                  []
# 4         NaN              NaN        39391                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL671073  Binding affinity to cloned human Dopamine rece...
# 1    CHEMBL671073  Binding affinity to cloned human Dopamine rece...
# 2    CHEMBL671073  Binding affinity to cloned human Dopamine rece...
# 3    CHEMBL671073  Binding affinity to cloned human Dopamine rece...
# 4    CHEMBL671073  Binding affinity to cloned human Dopamine rece...
#
#   assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0          B                      NaN                     NaN  BAO_0000190
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2475 entries, 0 to 2474
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   action_type                120 non-null    object
#  1   activity_comment           1164 non-null   object
#  2   activity_id                2475 non-null   int64
#  3   activity_properties        2475 non-null   object
#  4   assay_chembl_id            2475 non-null   object
#  5   assay_description          2475 non-null   object
#  6   assay_type                 2475 non-null   object
#  7   assay_variant_accession    0 non-null      float64
#  8   assay_variant_mutation     0 non-null      float64
#  9   bao_endpoint               2475 non-null   object
#  10  bao_format                 2475 non-null   object
#  11  bao_label                  2475 non-null   object
#  12  canonical_smiles           2437 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df['standard_value'].isna().sum()
# Out:
# np.int64(903)

# %%
df.isna().sum()
# Out:
# action_type                  2355
# activity_comment             1311
# activity_id                     0
# activity_properties             0
# assay_chembl_id                 0
# assay_description               0
# assay_type                      0
# assay_variant_accession      2475
# assay_variant_mutation       2475
# bao_endpoint                    0
# bao_format                      0
# bao_label                       0
# canonical_smiles               38
# data_validity_comment        2464
# data_validity_description    2464
# document_chembl_id              0
# document_journal             1139
# document_year                 875
# ligand_efficiency            1838
# molecule_chembl_id              0
# molecule_pref_name           1497
# parent_molecule_chembl_id       0
# pchembl_value                1384
# potential_duplicate             0
# qudt_units                    895
# record_id                       0
# relation                      907
# ...

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df2 = df[selection]

# %%
df2.dropna(inplace=True,axis=0)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11068\600528996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True,axis=0)

# %%
df2.shape
# Out:
# (1570, 3)

# %%
df['standard_type'].unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df['standard_units'].unique()
# Out:
# array(['nM', nan], dtype=object)

# %%
df['target_organism'].unique()
# Out:
# array(['Homo sapiens'], dtype=object)

# %%
df['target_pref_name'].unique()
# Out:
# array(['D(2) dopamine receptor'], dtype=object)

# %% [markdown]
# ### the data cleaning process and data validation is done by ensure that only useful column will be insert the training phase with no duplicates in data also make sure only ic50 standard value ,organism homo sapiens and only D2 dopamine are in the data

# %%
df2
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL303519          c1cnc(N2CCN(Cc3cccc4c3Cc3ccccc3-4)CC2)nc1
# 1          CHEMBL292943         COc1ccc(-c2cccc(CN3CCN(c4ncccn4)CC3)c2)cc1
# 2           CHEMBL61682         Fc1ccc(-c2cncc(CN3CCN(c4ccccc4F)CC3)c2)cc1
# 3           CHEMBL64487           COc1ccccc1-c1cccc(CN2CCN(c3ncccn3)CC2)c1
# 4           CHEMBL64597            c1cnc(N2CCN(Cc3cccc(-c4ccsc4)c3)CC2)nc1
# ...                 ...                                                ...
# 2470      CHEMBL5924660        COc1ccc(OCCCN2CCN(C(=O)c3ccc(Cl)cc3)CC2)cc1
# 2471      CHEMBL4459353         COc1ccc(OCCN(C)CCN(C)C(=O)c2ccc(OC)cc2)cc1
# 2472      CHEMBL4471482  COc1ccc(N(C)CCN2CCN(C(=O)c3cc4ccccc4[nH]3)CC2)cc1
# 2473      CHEMBL4442293    COc1ccc(OCCCN2CCN(C(=O)c3cc4ccccc4[nH]3)CC2)cc1
# 2474      CHEMBL4580359   COc1ccc(OCCCCN2CCN(C(=O)c3cc4ccccc4[nH]3)CC2)cc1
#
#       standard_value
# 0             9800.0
# 1               50.0
# ...

# %%
df2.isna().sum()
# Out:
# molecule_chembl_id    0
# canonical_smiles      0
# standard_value        0
# dtype: int64

# %%
df2.to_csv('..\Data\Dopamine_D2_receptor_02_bioactivity_data_raw.csv', index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\HP\AppData\Local\Temp\ipykernel_11068\394170536.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df2.to_csv('..\Data\Dopamine_D2_receptor_02_bioactivity_data_raw.csv', index=False)
